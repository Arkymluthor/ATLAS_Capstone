# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## REMODELING TORONTO DATA USING CUMMULATIVE COVID NUMBERS

# %%
df = pd.read_csv('model_data/Torontoaggregated.csv',index_col=0,parse_dates=True)

# %%
df['total_individuals_fully_vaccinated']= df['total_individuals_fully_vaccinated'].replace(np.nan,0)

# %%
df.columns
# Out:
# Index(['date', 'oh_region', 'ICU', 'ICU_vented', 'hospitalizations',
#        'icu_crci_total', 'icu_crci_total_vented', 'icu_former_covid_vented',
#        'Daily_Covid_Num', 'Cum_Covid_Numbers', 'covid_advice',
#        'total_doses_administered', 'total_individuals_fully_vaccinated'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 0 to 123
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                124 non-null    object
#  1   oh_region                           124 non-null    object
#  2   ICU                                 124 non-null    int64
#  3   ICU_vented                          124 non-null    int64
#  4   hospitalizations                    124 non-null    int64
#  5   icu_crci_total                      124 non-null    int64
#  6   icu_crci_total_vented               124 non-null    int64
#  7   icu_former_covid_vented             124 non-null    int64
#  8   Daily_Covid_Num                     124 non-null    int64
#  9   Cum_Covid_Numbers                   124 non-null    int64
#  10  covid_advice                        124 non-null    object
#  11  total_doses_administered            124 non-null    int64
#  12  total_individuals_fully_vaccinated  124 non-null    float64
# dtypes: float64(1), int64(9), object(3)
# memory usage: 13.6+ KB

# %%
df1 = df[['date', 'ICU', 'ICU_vented', 'hospitalizations',
       'icu_crci_total', 'icu_crci_total_vented',
       'total_individuals_fully_vaccinated',
       'Daily_Covid_Num']]


df2 = df[['date', 'ICU', 'ICU_vented', 'hospitalizations',
       'icu_crci_total', 'icu_crci_total_vented',
       'total_individuals_fully_vaccinated',
       'Cum_Covid_Numbers']]

# %%
# df1a['report_date'] =pd.to_datetime(df1a['report_date'])

# %%
df1['date'] =pd.to_datetime(df1['date'])
df1=df1.set_index('date')
df2['date'] =pd.to_datetime(df2['date'])
df2=df2.set_index('date')
# Out:
# <ipython-input-8-9a57376be025>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['date'] =pd.to_datetime(df1['date'])
# <ipython-input-8-9a57376be025>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['date'] =pd.to_datetime(df2['date'])

# %%
# df1 = df1a.drop('report_date',axis=1)
# df2 = df2a.drop('report_date',axis=1)

# %%
df1.head()
# Out:
#             ICU  ICU_vented  hospitalizations  icu_crci_total  \
# date
# 2020-12-24   59          37               159              67
# 2020-12-30   64          40               215              70
# 2020-12-31   70          43               212              75
# 2021-01-01   66          47               198              73
# 2021-01-02   65          44               203              71
#
#             icu_crci_total_vented  total_individuals_fully_vaccinated  \
# date
# 2020-12-24                     40                                 0.0
# 2020-12-30                     43                                 0.0
# 2020-12-31                     44                                 0.0
# 2021-01-01                     51                                 0.0
# 2021-01-02                     46                                 0.0
#
#             Daily_Covid_Num
# date
# 2020-12-24              844
# 2020-12-30              856
# 2020-12-31              853
# 2021-01-01              956
# 2021-01-02              938

# %%
df1['total_individuals_fully_vaccinated']= df1['total_individuals_fully_vaccinated']- df1['total_individuals_fully_vaccinated'].shift(1)

# %%
df1 = df1.replace(np.nan,0)

# %%
df1.head()
# Out:
#             ICU  ICU_vented  hospitalizations  icu_crci_total  \
# date
# 2020-12-24   59          37               159              67
# 2020-12-30   64          40               215              70
# 2020-12-31   70          43               212              75
# 2021-01-01   66          47               198              73
# 2021-01-02   65          44               203              71
#
#             icu_crci_total_vented  total_individuals_fully_vaccinated  \
# date
# 2020-12-24                     40                                 0.0
# 2020-12-30                     43                                 0.0
# 2020-12-31                     44                                 0.0
# 2021-01-01                     51                                 0.0
# 2021-01-02                     46                                 0.0
#
#             Daily_Covid_Num
# date
# 2020-12-24              844
# 2020-12-30              856
# 2020-12-31              853
# 2021-01-01              956
# 2021-01-02              938

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 124 entries, 2020-12-24 to 2021-05-01
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ICU                                 124 non-null    int64
#  1   ICU_vented                          124 non-null    int64
#  2   hospitalizations                    124 non-null    int64
#  3   icu_crci_total                      124 non-null    int64
#  4   icu_crci_total_vented               124 non-null    int64
#  5   total_individuals_fully_vaccinated  124 non-null    float64
#  6   Daily_Covid_Num                     124 non-null    int64
# dtypes: float64(1), int64(6)
# memory usage: 7.8 KB

# %%
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

# %%
df1.corr()
# Out:
#                                          ICU  ICU_vented  hospitalizations  \
# ICU                                 1.000000    0.970525          0.921797
# ICU_vented                          0.970525    1.000000          0.927020
# hospitalizations                    0.921797    0.927020          1.000000
# icu_crci_total                      0.996609    0.966927          0.901512
# icu_crci_total_vented               0.960506    0.993801          0.896695
# total_individuals_fully_vaccinated -0.190915   -0.136562         -0.248059
# Daily_Covid_Num                     0.555923    0.473659          0.647333
#
#                                     icu_crci_total  icu_crci_total_vented  \
# ICU                                       0.996609               0.960506
# ICU_vented                                0.966927               0.993801
# hospitalizations                          0.901512               0.896695
# icu_crci_total                            1.000000               0.963551
# icu_crci_total_vented                     0.963551               1.000000
# total_individuals_fully_vaccinated       -0.186142              -0.093022
# Daily_Covid_Num                           0.526363               0.403550
#
#                                     total_individuals_fully_vaccinated  \
# ICU                                                          -0.190915
# ICU_vented                                                   -0.136562
# hospitalizations                                             -0.248059
# icu_crci_total                                               -0.186142
# icu_crci_total_vented                                        -0.093022
# total_individuals_fully_vaccinated                            1.000000
# Daily_Covid_Num                                              -0.529578
#
#                                     Daily_Covid_Num
# ICU                                        0.555923
# ICU_vented                                 0.473659
# hospitalizations                           0.647333
# icu_crci_total                             0.526363
# icu_crci_total_vented                      0.403550
# total_individuals_fully_vaccinated        -0.529578
# Daily_Covid_Num                            1.000000

# %%
matrix = np.triu(df1.corr())

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df1.corr(),mask=matrix,cmap='viridis',annot=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df2.corr(),mask=np.triu(df2.corr()),cmap='plasma',annot=True)
plt.show()

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data,variables, test='ssr_chi2test', verbose=False):    
    """
    To check that coefficients of past values influences the present value
    
    Null hypothesis: The coefficients of past values in the times series are equal to zero 
    

   Response variableaa: rows, Predictors:columns
   The values in the table are the P-Values. P-Values lesser than the significance level (0.05), 
   implies the Null hypothesis that the coefficients of the corresponding past values is zero,
    that is, the X does not cause Y can be rejected.

    data      : dataframe containing the time series variables
    variables : names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(df1, variables = df1.columns)
# Out:
#                                        ICU_x  ICU_vented_x  \
# ICU_y                                 1.0000        0.0018
# ICU_vented_y                          0.0000        1.0000
# hospitalizations_y                    0.0028        0.0006
# icu_crci_total_y                      0.0070        0.0000
# icu_crci_total_vented_y               0.0000        0.0005
# total_individuals_fully_vaccinated_y  0.0062        0.0800
# Daily_Covid_Num_y                     0.0005        0.0028
#
#                                       hospitalizations_x  icu_crci_total_x  \
# ICU_y                                             0.0047            0.1116
# ICU_vented_y                                      0.0000            0.0001
# hospitalizations_y                                1.0000            0.0014
# icu_crci_total_y                                  0.0025            1.0000
# icu_crci_total_vented_y                           0.0000            0.0000
# total_individuals_fully_vaccinated_y              0.0160            0.0031
# Daily_Covid_Num_y                                 0.0000            0.0007
#
#                                       icu_crci_total_vented_x  \
# ICU_y                                                  0.0003
# ICU_vented_y                                           0.0018
# hospitalizations_y                                     0.0002
# icu_crci_total_y                                       0.0000
# icu_crci_total_vented_y                                1.0000
# total_individuals_fully_vaccinated_y                   0.0935
# Daily_Covid_Num_y                                      0.0019
#
#                                       total_individuals_fully_vaccinated_x  \
# ICU_y                                                               0.0677
# ICU_vented_y                                                        0.0039
# hospitalizations_y                                                  0.0011
# icu_crci_total_y                                                    0.0837
# icu_crci_total_vented_y                                             0.0058
# total_individuals_fully_vaccinated_y                                1.0000
# Daily_Covid_Num_y                                                   0.0001
#
#                                       Daily_Covid_Num_x
# ICU_y                                            0.0000
# ICU_vented_y                                     0.0000
# hospitalizations_y                               0.0000
# icu_crci_total_y                                 0.0000
# icu_crci_total_vented_y                          0.0000
# total_individuals_fully_vaccinated_y             0.0075
# Daily_Covid_Num_y                                1.0000

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

# def cointegration_test(df, alpha=0.05): 
#     """Perform Johanson's Cointegration Test and Report Summary"""
#     out = coint_johansen(df,-1,5)
#     d = {'0.90':0, '0.95':1, '0.99':2}
#     traces = out.lr1
#     cvts = out.cvt[:, d[str(1-alpha)]]
#     def adjust(val, length= 6): return str(val).ljust(length)

#     # Summary
#     print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
#     for col, trace, cvt in zip(df.columns, traces, cvts):
#         print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

# cointegration_test(df1)

# %%
 #out = coint_johansen(df,-1,5)

# %%
nobs = 7 #number of days to forecast 
df1_train, df1_test = df1[0:-nobs], df1[-nobs:]

# Check size
print(df1_train.shape) 
print(df1_test.shape)
# Out:
# (117, 7)
# (7, 7)

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """
    Performing Augumented Dick-Fuller test to check Stationarity of given series and print report
    
    """
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f' Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-----------------------------------------------------')
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
# ADF Test on each column
for name, column in df1_train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#  Augmented Dickey-Fuller Test on "ICU"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 2.1811
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.488
#  Critical value 5%     = -2.887
#  Critical value 10%    = -2.58
#  => P-Value = 0.9989. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "ICU_vented"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.4018
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.49
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.9098. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "hospitalizations"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.3912
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.492
#  Critical value 5%     = -2.889
#  Critical value 10%    = -2.581
#  => P-Value = 0.1442. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "icu_crci_total"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 1.8237
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.489
#  Critical value 5%     = -2.887
#  Critical value 10%    = -2.58
#  => P-Value = 0.9984. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "icu_crci_total_vented"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.2567
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.491
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.6487. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "total_individuals_fully_vaccinated"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.4287
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.492
#  Critical value 5%     = -2.889
#  Critical value 10%    = -2.581
#  => P-Value = 0.1338. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "Daily_Covid_Num"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.7263
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.492
#  Critical value 5%     = -2.889
#  Critical value 10%    = -2.581
#  => P-Value = 0.4176. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
# 1st difference since all series are non-stationary
df1_differenced = df1_train.diff().dropna()

# %%
# ADF Test on each column of 1st Differences Dataframe
for name, column in df1_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#  Augmented Dickey-Fuller Test on "ICU"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.6293
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.491
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.0871. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "ICU_vented"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.7873
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.49
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.003. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  Augmented Dickey-Fuller Test on "hospitalizations"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.4545
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.491
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.1269. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "icu_crci_total"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.7621
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.491
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.0639. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "icu_crci_total_vented"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.8311
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.491
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.054. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#  Augmented Dickey-Fuller Test on "total_individuals_fully_vaccinated"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.9882
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.492
#  Critical value 5%     = -2.889
#  Critical value 10%    = -2.581
#  => P-Value = 0.036. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  Augmented Dickey-Fuller Test on "Daily_Covid_Num"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.1241
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.496
#  Critical value 5%     = -2.89
#  Critical value 10%    = -2.582
#  => P-Value = 0.7054. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
#2nd differencing as some terms are still non-stationary 
df1_differenced = df1_differenced.diff().dropna()

# %%
for name, column in df1_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#  Augmented Dickey-Fuller Test on "ICU"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -10.8635
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.491
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  Augmented Dickey-Fuller Test on "ICU_vented"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -9.7892
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.491
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  Augmented Dickey-Fuller Test on "hospitalizations"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -7.9312
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.492
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  Augmented Dickey-Fuller Test on "icu_crci_total"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -10.0879
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.491
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  Augmented Dickey-Fuller Test on "icu_crci_total_vented"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -10.7539
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.491
#  Critical value 5%     = -2.888
#  Critical value 10%    = -2.581
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  Augmented Dickey-Fuller Test on "total_individuals_fully_vaccinated"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -9.5471
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.492
#  Critical value 5%     = -2.889
#  Critical value 10%    = -2.581
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#  Augmented Dickey-Fuller Test on "Daily_Covid_Num"
#     -----------------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.9161
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.497
#  Critical value 5%     = -2.891
#  Critical value 10%    = -2.582
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
#3rd differencing as some terms are still non-stationary 

#df1_differenced = df1_differenced.diff().dropna()

# %%
# for name, column in df1_differenced.iteritems():
#     adfuller_test(column, name=column.name)
#     print('\n')

# %%
model = VAR(df1_differenced)
for i in range(1,10,1):
    result = model.fit(i)
    print('Lag Order =', i)
    print('AIC : ', result.aic)
    print('BIC : ', result.bic)
    print('FPE : ', result.fpe)
    print('HQIC: ', result.hqic, '\n')
# Out:
# Lag Order = 1
# AIC :  36.13031663326211
# BIC :  37.47441411668397
# FPE :  4919258227398678.0
# HQIC:  36.67581047069357
#
# Lag Order = 2
# AIC :  35.453719041716965
# BIC :  37.98801745733462
# FPE :  2524328442290777.0
# HQIC:  36.48211095559378
#
# Lag Order = 3
# AIC :  34.907794080517704
# BIC :  38.645730028548456
# FPE :  1499645269216324.5
# HQIC:  36.424393542012425
#
# Lag Order = 4
# AIC :  34.632221791562735
# BIC :  39.58748873630511
# FPE :  1197516664653865.5
# HQIC:  36.64242712662869
#
# Lag Order = 5
# AIC :  34.230611995025455
# BIC :  40.41716701484081
# FPE :  875297122079161.5
# HQIC:  36.73991211617538
#
# Lag Order = 6
# AIC :  34.10413483021436
# BIC :  41.53620558756273
# FPE :  888698813998495.2
# HQIC:  37.11811099105893
#
# Lag Order = 7
# AIC :  34.332404779148774
# BIC :  43.024496718903194
# FPE :  1387094206557769.5
# HQIC:  37.85673235023562
#
# Lag Order = 8
# AIC :  34.35838077903707
# BIC :  44.32528456361931
# FPE :  1967107944561614.5
# HQIC:  38.39883104327671
#
# Lag Order = 9
# AIC :  33.71538836863294
# BIC :  44.97218755884242
# FPE :  1666429837903399.0
# HQIC:  38.27783033431322
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'

# %%
x=model.select_order(maxlags=maxlag)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
fitted_model = model.fit(2)

# %%
fitted_model.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 10, May, 2021
# Time:                     09:50:34
# --------------------------------------------------------------------
# No. of Equations:         7.00000    BIC:                    37.9880
# Nobs:                     113.000    HQIC:                   36.4821
# Log likelihood:          -3020.52    FPE:                2.52433e+15
# AIC:                      35.4537    Det(Omega_mle):     1.05493e+15
# --------------------------------------------------------------------
# Results for equation ICU
# ========================================================================================================
#                                            coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------
# const                                         0.049498         0.385434            0.128           0.898
# L1.ICU                                       -0.845746         0.235801           -3.587           0.000
# L1.ICU_vented                                 0.251794         0.234175            1.075           0.282
# L1.hospitalizations                          -0.014199         0.030594           -0.464           0.643
# L1.icu_crci_total                             0.215125         0.219981            0.978           0.328
# L1.icu_crci_total_vented                     -0.265415         0.204273           -1.299           0.194
# L1.total_individuals_fully_vaccinated         0.000340         0.000924            0.368           0.713
# L1.Daily_Covid_Num                           -0.002151         0.003770           -0.570           0.568
# L2.ICU                                       -0.261040         0.229394           -1.138           0.255
# L2.ICU_vented                                 0.144061         0.233057            0.618           0.536
# L2.hospitalizations                          -0.025636         0.028064           -0.913           0.361
# L2.icu_crci_total                            -0.049655         0.217394           -0.228           0.819
# L2.icu_crci_total_vented                     -0.139103         0.203324           -0.684           0.494
# L2.total_individuals_fully_vaccinated         0.000374         0.000893            0.419           0.675
# L2.Daily_Covid_Num                            0.002168         0.004065            0.533           0.594
# ========================================================================================================
#
# Results for equation ICU_vented
# ========================================================================================================
#                                            coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------
# const                                        -0.065718         0.483659           -0.136           0.892
# L1.ICU                                        0.229598         0.295893            0.776           0.438
# L1.ICU_vented                                -1.287124         0.293852           -4.380           0.000
# L1.hospitalizations                           0.008910         0.038391            0.232           0.816
# L1.icu_crci_total                            -0.006066         0.276042           -0.022           0.982
# L1.icu_crci_total_vented                      0.342898         0.256330            1.338           0.181
# L1.total_individuals_fully_vaccinated        -0.000316         0.001160           -0.273           0.785
# L1.Daily_Covid_Num                            0.006276         0.004730            1.327           0.185
# L2.ICU                                        0.314415         0.287853            1.092           0.275
# L2.ICU_vented                                -0.702464         0.292449           -2.402           0.016
# L2.hospitalizations                          -0.029908         0.035216           -0.849           0.396
# L2.icu_crci_total                            -0.280457         0.272795           -1.028           0.304
# L2.icu_crci_total_vented                      0.231740         0.255139            0.908           0.364
# L2.total_individuals_fully_vaccinated        -0.001615         0.001121           -1.440           0.150
# L2.Daily_Covid_Num                            0.009083         0.005101            1.781           0.075
# ========================================================================================================
#
# Results for equation hospitalizations
# ========================================================================================================
#                                            coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------
# const                                         0.043237         1.205686            0.036           0.971
# L1.ICU                                       -0.074416         0.737615           -0.101           0.920
# L1.ICU_vented                                 0.242178         0.732527            0.331           0.741
# L1.hospitalizations                          -0.700949         0.095703           -7.324           0.000
# L1.icu_crci_total                             0.063435         0.688129            0.092           0.927
# L1.icu_crci_total_vented                      0.126556         0.638991            0.198           0.843
# L1.total_individuals_fully_vaccinated        -0.003525         0.002892           -1.219           0.223
# L1.Daily_Covid_Num                            0.032162         0.011792            2.727           0.006
# L2.ICU                                       -0.001917         0.717574           -0.003           0.998
# L2.ICU_vented                                -0.936593         0.729031           -1.285           0.199
# L2.hospitalizations                          -0.189840         0.087788           -2.162           0.031
# L2.icu_crci_total                             0.157663         0.680036            0.232           0.817
# L2.icu_crci_total_vented                      0.738972         0.636022            1.162           0.245
# L2.total_individuals_fully_vaccinated        -0.002028         0.002794           -0.726           0.468
# L2.Daily_Covid_Num                            0.011307         0.012715            0.889           0.374
# ========================================================================================================
#
# Results for equation icu_crci_total
# ========================================================================================================
#                                            coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------
# const                                         0.040108         0.389879            0.103           0.918
# L1.ICU                                        0.013500         0.238521            0.057           0.955
# L1.ICU_vented                                 0.023768         0.236875            0.100           0.920
# L1.hospitalizations                          -0.020855         0.030947           -0.674           0.500
# L1.icu_crci_total                            -0.557102         0.222519           -2.504           0.012
# L1.icu_crci_total_vented                     -0.082923         0.206629           -0.401           0.688
# L1.total_individuals_fully_vaccinated         0.000559         0.000935            0.598           0.550
# L1.Daily_Covid_Num                            0.000566         0.003813            0.149           0.882
# L2.ICU                                        0.154847         0.232040            0.667           0.505
# L2.ICU_vented                                -0.016069         0.235745           -0.068           0.946
# L2.hospitalizations                          -0.009972         0.028388           -0.351           0.725
# L2.icu_crci_total                            -0.406516         0.219901           -1.849           0.065
# L2.icu_crci_total_vented                      0.005677         0.205669            0.028           0.978
# L2.total_individuals_fully_vaccinated         0.000798         0.000904            0.883           0.377
# L2.Daily_Covid_Num                            0.004201         0.004112            1.022           0.307
# ========================================================================================================
#
# Results for equation icu_crci_total_vented
# ========================================================================================================
#                                            coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------
# const                                        -0.083055         0.537778           -0.154           0.877
# L1.ICU                                        0.322323         0.329002            0.980           0.327
# L1.ICU_vented                                -0.608691         0.326732           -1.863           0.062
# L1.hospitalizations                           0.016773         0.042687            0.393           0.694
# L1.icu_crci_total                            -0.003389         0.306930           -0.011           0.991
# L1.icu_crci_total_vented                     -0.398325         0.285012           -1.398           0.162
# L1.total_individuals_fully_vaccinated        -0.000102         0.001290           -0.079           0.937
# L1.Daily_Covid_Num                            0.003458         0.005260            0.657           0.511
# L2.ICU                                        0.376561         0.320063            1.177           0.239
# L2.ICU_vented                                -0.387023         0.325173           -1.190           0.234
# L2.hospitalizations                          -0.016274         0.039156           -0.416           0.678
# L2.icu_crci_total                            -0.240452         0.303320           -0.793           0.428
# L2.icu_crci_total_vented                     -0.126009         0.283688           -0.444           0.657
# L2.total_individuals_fully_vaccinated        -0.001678         0.001246           -1.346           0.178
# L2.Daily_Covid_Num                            0.007146         0.005672            1.260           0.208
# ========================================================================================================
#
# Results for equation total_individuals_fully_vaccinated
# ========================================================================================================
#                                            coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------
# const                                         0.016227        40.228293            0.000           1.000
# L1.ICU                                      -10.908013        24.610888           -0.443           0.658
# L1.ICU_vented                                 1.387066        24.441120            0.057           0.955
# L1.hospitalizations                          -4.962856         3.193178           -1.554           0.120
# L1.icu_crci_total                            -0.970899        22.959772           -0.042           0.966
# L1.icu_crci_total_vented                     11.538744        21.320264            0.541           0.588
# L1.total_individuals_fully_vaccinated        -0.434229         0.096484           -4.501           0.000
# L1.Daily_Covid_Num                            1.063971         0.393454            2.704           0.007
# L2.ICU                                       -4.218355        23.942194           -0.176           0.860
# L2.ICU_vented                               -19.530305        24.324482           -0.803           0.422
# L2.hospitalizations                           1.201538         2.929077            0.410           0.682
# L2.icu_crci_total                           -18.221419        22.689723           -0.803           0.422
# L2.icu_crci_total_vented                     20.658246        21.221171            0.973           0.330
# L2.total_individuals_fully_vaccinated        -0.263245         0.093235           -2.823           0.005
# L2.Daily_Covid_Num                            0.617514         0.424255            1.456           0.146
# ========================================================================================================
#
# Results for equation Daily_Covid_Num
# ========================================================================================================
#                                            coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------------------------
# const                                        -1.623874         9.128072           -0.178           0.859
# L1.ICU                                        0.940002         5.584377            0.168           0.866
# L1.ICU_vented                                -1.484586         5.545855           -0.268           0.789
# L1.hospitalizations                          -0.249668         0.724554           -0.345           0.730
# L1.icu_crci_total                            -1.657434         5.209727           -0.318           0.750
# L1.icu_crci_total_vented                      1.322683         4.837712            0.273           0.785
# L1.total_individuals_fully_vaccinated        -0.052908         0.021893           -2.417           0.016
# L1.Daily_Covid_Num                           -0.878410         0.089277           -9.839           0.000
# L2.ICU                                        9.820850         5.432646            1.808           0.071
# L2.ICU_vented                                -4.777287         5.519389           -0.866           0.387
# L2.hospitalizations                           0.377931         0.664627            0.569           0.570
# L2.icu_crci_total                           -13.066763         5.148451           -2.538           0.011
# L2.icu_crci_total_vented                      2.909534         4.815227            0.604           0.546
# L2.total_individuals_fully_vaccinated        -0.059467         0.021156           -2.811           0.005
# L2.Daily_Covid_Num                           -0.369437         0.096266           -3.838           0.000
# ========================================================================================================
#
# Correlation matrix of residuals
#                                            ICU  ICU_vented  hospitalizations  icu_crci_total  icu_crci_total_vented  total_individuals_fully_vaccinated  Daily_Covid_Num
# ICU                                   1.000000    0.346254          0.034588        0.889892               0.217262                           -0.091539         0.035898
# ICU_vented                            0.346254    1.000000         -0.076025        0.202476               0.929886                            0.008781        -0.007851
# hospitalizations                      0.034588   -0.076025          1.000000        0.001837              -0.148282                           -0.062214         0.082650
# icu_crci_total                        0.889892    0.202476          0.001837        1.000000               0.156650                           -0.118560         0.023651
# icu_crci_total_vented                 0.217262    0.929886         -0.148282        0.156650               1.000000                            0.033828        -0.053576
# total_individuals_fully_vaccinated   -0.091539    0.008781         -0.062214       -0.118560               0.033828                            1.000000         0.141433
# Daily_Covid_Num                       0.035898   -0.007851          0.082650        0.023651              -0.053576                            0.141433         1.000000

# %%
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(fitted_model.resid)

for col, val in zip(df.columns, out):
    print(col, ':', round(val, 2))
# Out:
# date : 2.15
# oh_region : 2.32
# ICU : 2.15
# ICU_vented : 2.11
# hospitalizations : 2.34
# icu_crci_total : 2.01
# icu_crci_total_vented : 2.24

# %%
lag_order = fitted_model.k_ar

lag_order
# Out:
# 2

# %%
forecast_input = df1_differenced.values[-lag_order:]
forecast_input
# Out:
# array([[   6.     ,    9.     ,   13.     ,    2.     ,   10.     ,
#          462.02463,  220.     ],
#        [   5.     ,   -7.     ,    8.     ,    8.     ,  -11.     ,
#         -580.39018, -214.     ]])

# %%
fc = fitted_model.forecast(y=forecast_input, steps=nobs)
df_forecast = pd.DataFrame(fc, index=df.index[-nobs:], columns=df1.columns + '_2d')
df_forecast
# Out:
#        ICU_2d  ICU_vented_2d  hospitalizations_2d  icu_crci_total_2d  \
# 117 -2.595701       3.367815           -15.006521          -3.024794
# 118 -1.653335      -1.381241            13.745608          -2.438998
# 119  1.961005       1.703452            -5.218483           2.624610
# 120 -0.210376      -2.173407            -0.536296          -0.557964
# 121 -0.622244       1.251981             0.297198          -0.386271
# 122  0.547272      -0.009891             1.266913           0.409405
# 123 -0.209347      -0.757007            -0.742793          -0.295059
#
#      icu_crci_total_vented_2d  total_individuals_fully_vaccinated_2d  \
# 117                  7.217877                            -215.393027
# 118                 -2.289359                             184.998600
# 119                  0.269285                              82.948264
# 120                 -0.634757                             -55.936607
# 121                  0.756075                             -80.056701
# 122                 -0.243161                              78.162602
# 123                 -0.495045                              -3.239534
#
#      Daily_Covid_Num_2d
# 117          117.401911
# 118          -19.884603
# 119          -13.157351
# 120           19.278497
# 121          -36.785727
# 122           43.809501
# 123          -31.411202

# %%
def invert_transformation(df_train, df_forecast, third_diff=False,second_diff=False):
    """
    Transforming the forecast numbers to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back Differences
        if third_diff:
            df_fc[str(col)+'_2d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_3d'].cumsum()  
            
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_2d'].cumsum()       
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc

# %%
df_results = invert_transformation(df1_train, df_forecast, third_diff=False,second_diff=True)

# %%
df_results.columns
# Out:
# Index(['ICU_2d', 'ICU_vented_2d', 'hospitalizations_2d', 'icu_crci_total_2d',
#        'icu_crci_total_vented_2d', 'total_individuals_fully_vaccinated_2d',
#        'Daily_Covid_Num_2d', 'ICU_1d', 'ICU_forecast', 'ICU_vented_1d',
#        'ICU_vented_forecast', 'hospitalizations_1d',
#        'hospitalizations_forecast', 'icu_crci_total_1d',
#        'icu_crci_total_forecast', 'icu_crci_total_vented_1d',
#        'icu_crci_total_vented_forecast',
#        'total_individuals_fully_vaccinated_1d',
#        'total_individuals_fully_vaccinated_forecast', 'Daily_Covid_Num_1d',
#        'Daily_Covid_Num_forecast'],
#       dtype='object')

# %%
df1_forecasted = df_results[['ICU_forecast','ICU_vented_forecast','hospitalizations_forecast','icu_crci_total_forecast','icu_crci_total_vented_forecast','total_individuals_fully_vaccinated_forecast','Daily_Covid_Num_forecast']]

# %%
# df1_forecasted = df_results[['ICU_forecast','ICU_vented_forecast','hospitalizations_forecast','icu_crci_total_forecast','icu_crci_total_vented_forecast','total_individuals_fully_vaccinated_forecast','Cum_Covid_Numbers_forecast']]

# %%
#df1.tail(nobs)

df1_forecasted
# Out:
#      ICU_forecast  ICU_vented_forecast  hospitalizations_forecast  \
# 117    154.404299           108.367815                 363.993479
# 118    157.155264           108.354388                 367.732565
# 119    161.867233           110.044414                 366.253169
# 120    166.368827           109.561033                 364.237476
# 121    170.248176           110.329633                 362.518982
# 122    174.674798           111.088342                 362.067401
# 123    178.892073           111.090044                 360.873026
#
#      icu_crci_total_forecast  icu_crci_total_vented_forecast  \
# 117               171.975206                      120.217877
# 118               173.511414                      120.146395
# 119               177.672232                      120.344198
# 120               181.275085                      119.907244
# 121               184.491667                      120.226365
# 122               188.117654                      120.302325
# 123               191.448581                      119.883240
#
#      total_individuals_fully_vaccinated_forecast  Daily_Covid_Num_forecast
# 117                                   657.586153                841.401911
# 118                                   551.118585                801.919219
# 119                                   527.599281                749.279176
# 120                                   448.143370                715.917631
# 121                                   288.630758                645.770359
# 122                                   207.280748                619.432587
# 123                                   122.691204                561.683614

# %%
df1_test
# Out:
#             ICU  ICU_vented  hospitalizations  icu_crci_total  \
# date
# 2021-04-25  156         105               380             174
# 2021-04-26  158         111               389             176
# 2021-04-27  161         111               384             179
# 2021-04-28  147         100               364             168
# 2021-04-29  147         100               363             168
# 2021-04-30  152         105               351             173
# 2021-05-01  157         105               354             180
#
#             icu_crci_total_vented  total_individuals_fully_vaccinated  \
# date
# 2021-04-25                    115                           419.73222
# 2021-04-26                    124                           215.98388
# 2021-04-27                    124                           371.58803
# 2021-04-28                    114                           692.37197
# 2021-04-29                    117                           861.00963
# 2021-04-30                    121                           720.03493
# 2021-05-01                    123                           651.40951
#
#             Daily_Covid_Num
# date
# 2021-04-25              707
# 2021-04-26              765
# 2021-04-27              742
# 2021-04-28              788
# 2021-04-29              688
# 2021-04-30              660
# 2021-05-01              624

# %%
def accuracy_score(forecast,actual):
    rmse = np.sqrt(np.mean((forecast - actual)**2))
    mape = 100 * np.mean(np.abs(forecast - actual)/np.abs(actual))
    merr = np.mean(np.abs(forecast - actual))
    
    return ({'mean_absolute_pcnt_error':f'{np.round(mape,2)} %', 'root_mean_squared_error' : rmse, 'mean_absolute_error':merr})

# %%
accuracy_score(df1_test.iloc[:,1],df1_forecasted.iloc[:,1].values)
# Out:
# {'mean_absolute_pcnt_error': '5.07 %',
#  'root_mean_squared_error': 6.453413242465048,
#  'mean_absolute_error': 5.576866239282483}

# %%
for i in range(len(df1_test.columns)):
    print('\n')
    print(f'printing the accuracy score of {df1_test.columns[i]}')
    score= accuracy_score(df1_test.iloc[:,i],df1_forecasted.iloc[:,i].values)
    print('----------------------------------------------')
    print(score)
# Out:
# printing the accuracy score of ICU
# ----------------------------------------------
# {'mean_absolute_pcnt_error': '7.52 %', 'root_mean_squared_error': 16.531573234012434, 'mean_absolute_error': 12.927363487243484}
#
#
# printing the accuracy score of ICU_vented
# ----------------------------------------------
# {'mean_absolute_pcnt_error': '5.07 %', 'root_mean_squared_error': 6.453413242465048, 'mean_absolute_error': 5.576866239282483}
#
#
# printing the accuracy score of hospitalizations
# ----------------------------------------------
# {'mean_absolute_pcnt_error': '2.88 %', 'root_mean_squared_error': 13.057434540587808, 'mean_absolute_error': 10.525672783122786}
#
#
# printing the accuracy score of icu_crci_total
# ----------------------------------------------
# {'mean_absolute_pcnt_error': '4.81 %', 'root_mean_squared_error': 10.82241214316898, 'mean_absolute_error': 8.882019277072809}
#
#
# printing the accuracy score of icu_crci_total_vented
# ----------------------------------------------
# {'mean_absolute_pcnt_error': '3.05 %', 'root_mean_squared_error': 3.9811575983367957, 'mean_absolute_error': 3.6679040765297453}
#
#
# printing the accuracy score of total_individuals_fully_vaccinated
# ----------------------------------------------
# {'mean_absolute_pcnt_error': '151.09 %', 'root_mean_squared_error': 400.52721595853825, 'mean_absolute_error': 369.58283558435147}
#
#
# printing the accuracy score of Daily_Covid_Num
# ----------------------------------------------
# {'mean_absolute_pcnt_error': '7.97 %', 'root_mean_squared_error': 67.59981647169423, 'mean_absolute_error': 56.54230217033312}

# %%
df1
# Out:
#             ICU  ICU_vented  hospitalizations  icu_crci_total  \
# date
# 2020-12-24   59          37               159              67
# 2020-12-30   64          40               215              70
# 2020-12-31   70          43               212              75
# 2021-01-01   66          47               198              73
# 2021-01-02   65          44               203              71
# ...         ...         ...               ...             ...
# 2021-04-27  161         111               384             179
# 2021-04-28  147         100               364             168
# 2021-04-29  147         100               363             168
# 2021-04-30  152         105               351             173
# 2021-05-01  157         105               354             180
#
#             icu_crci_total_vented  total_individuals_fully_vaccinated  \
# date
# 2020-12-24                     40                             0.00000
# 2020-12-30                     43                             0.00000
# 2020-12-31                     44                             0.00000
# 2021-01-01                     51                             0.00000
# 2021-01-02                     46                             0.00000
# ...                           ...                                 ...
# 2021-04-27                    124                           371.58803
# 2021-04-28                    114                           692.37197
# 2021-04-29                    117                           861.00963
# 2021-04-30                    121                           720.03493
# 2021-05-01                    123                           651.40951
#
#             Daily_Covid_Num
# date
# 2020-12-24              844
# 2020-12-30              856
# 2020-12-31              853
# 2021-01-01              956
# 2021-01-02              938
# ...                     ...
# 2021-04-27              742
# 2021-04-28              788
# 2021-04-29              688
# 2021-04-30              660
# 2021-05-01              624
#
# [124 rows x 7 columns]

# %%
df1.index
# Out:
# DatetimeIndex(['2020-12-24', '2020-12-30', '2020-12-31', '2021-01-01',
#                '2021-01-02', '2021-01-03', '2021-01-04', '2021-01-05',
#                '2021-01-06', '2021-01-07',
#                ...
#                '2021-04-22', '2021-04-23', '2021-04-24', '2021-04-25',
#                '2021-04-26', '2021-04-27', '2021-04-28', '2021-04-29',
#                '2021-04-30', '2021-05-01'],
#               dtype='datetime64[ns]', name='date', length=124, freq=None)

# %%
for i in range(0,len(df1.columns)):
    plt.figure(figsize=(20,12))
    sns.lineplot(x=df1.index[-30:],y=df1.iloc[-30:,i],marker='*')
    sns.lineplot(x=df1_test.index,y=df1_forecasted.iloc[:,i],marker='o')
    plt.xticks(fontsize=12)
    plt.ylim(np.min(df1.iloc[-30:,i])*0.9,np.max(df1.iloc[-30:,i])*1.5)
    plt.show()

# %%
# for i in range(1,len(df1.columns)):
#     plt.figure(figsize=(20,12))
#     sns.lineplot(x=df1a['report_date'][-30:],y=df1.iloc[-30:,i],marker='*')
#     sns.lineplot(x=df1a['report_date'][-nobs:],y=df1_forecasted.iloc[:,i],marker='o')
#     plt.xticks(fontsize=12)
#     plt.show()
